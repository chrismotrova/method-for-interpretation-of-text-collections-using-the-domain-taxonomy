# %%
import pandas as pd

# %%
df = pd.read_csv("arxiv_embeddings.csv")
print(df.columns)
# Out:
# Index(['id', 'title', 'categories', 'title_tokenized', 'categories_tokenized',
#        'categories_vectors'],
#       dtype='object')

# %%
titles = []

for a in df['title']:
    titles.append(a)

# %%
import re

import numpy as np

from east.asts import base


def clear_text(text, lowerize=True):

    pat = re.compile(r'[^A-Za-z0-9 \-\n\r.,;!?А-Яа-я]+')
    cleared_text = re.sub(pat, ' ', text)

    if lowerize:
        cleared_text = cleared_text.lower()

    tokens = cleared_text.split()
    return tokens


def make_substrings(tokens, k=4):

    for i in range(max(len(tokens) - k + 1, 1)):
        yield ' '.join(tokens[i:i + k])


def get_relevance_matrix(texts, strings):

    matrix = np.empty((0, len(strings)), float)
    prepared_text_tokens = [clear_text(t) for t in texts]

    prepared_string_tokens = [clear_text(s) for s in strings]
    prepared_strings = [' '.join(t) for t in prepared_string_tokens]

    for text_tokens in prepared_text_tokens:
        ast = base.AST.get_ast(list(make_substrings(text_tokens)))
        row = np.array([ast.score(s) for s in prepared_strings])
        matrix = np.append(matrix, [row], axis=0)

    return matrix


def save_matrix(matrix):
    np.savetxt("relevance_matrix.txt", matrix)

# %%
with open("taxonomy_leaves.txt") as f:
    strings = [l.strip() for l in f.readlines()]

# %%
relevance_matrix = get_relevance_matrix(titles[:1500], strings)
save_matrix(relevance_matrix)

# %%
import numpy as np
import numpy.linalg as LA

ZERO_BOUND = 10 ** (-9)
MIN_CLUSTER_CONTRIBUTION = 5 * 10 ** (-3)
EPSILON = 5 * 10 ** (-2)
# Maximum number of clusters
MAX_NUM_CLUSTERS = 15


def ensure_np_matrix(A):

    if not isinstance(A, np.matrix):
        A = np.matrix(A)
    return A


def faddis(A):
    A = ensure_np_matrix(A)
    
    # minimum cluster's relative contribution to the data scatter
    min_cont = MIN_CLUSTER_CONTRIBUTION
    # minimum relative residual data scatter
    eps = EPSILON
    # maximum number of clusters
    max_clust_num = MAX_NUM_CLUSTERS

    is_positive = True
    matrix_dim, _ = A.shape

    sc = np.power(A, 2)
    # Total data scatter
    scatter = np.sum(sc)

    cluster_got = 0
    membership_matrix = np.empty((matrix_dim, 0))
    contrib = np.array([])
    lat = np.array([])
    intensities = np.empty((0, 2))
    curr_cont = 1
    res_cont = 1

    # 'zero' and 'one' vectors for comparisons
    zeros_vect = np.zeros((matrix_dim, 1))
    ones_vect = np.ones((matrix_dim, 1))

    # ensure matrix is symmetrical
    At = (A + A.T) / 2
    matrix_sequence = [At]

    # Stop condition:
    # is_positive is True: eigen-value of the residual matrix is not positive;
    # OR la cluster intensity  reaches its minimum lam;
    # OR ep relative residual data scatter reaches its minimum eps;
    # OR maximum number of clusters max_clust_num is achieved
    while is_positive and curr_cont > min_cont and res_cont > eps and cluster_got <= max_clust_num:
        # collecting a fuzzy cluster membership uf, with contrib con and intensity la,
        eig_vals, eig_vecs = LA.eig(At)
        # (lt, ii) - (maximum eigen-value, corresponding position)
        eig_vals_diag = np.diag(eig_vals)
        # Only positive eigenvalues
        eig_vals_pos = np.argwhere(eig_vals > ZERO_BOUND).ravel()
        eig_vals_pos_len = eig_vals_pos.size
        cur_intensities = np.zeros((eig_vals_pos_len, 1))
        vm = np.zeros((matrix_dim, eig_vals_pos_len))
        for k in range(eig_vals_pos_len):
            lt = eig_vals_diag[eig_vals_pos[k]]
            vf = eig_vecs[:, eig_vals_pos[k]]

            # Calculate normalized membership vector belonging to [0, 1] by
            # projection on the space. The normalization factor is the
            # Euclidean length of the vector
            bf = np.maximum(zeros_vect, vf)
            uf = np.minimum(bf, ones_vect)
            
            if LA.norm(uf) > 0:
                uf = uf / LA.norm(uf)

            vt = uf.T.dot(At).dot(uf)
            uf = np.squeeze(np.asarray(uf))

            wt = uf.T.dot(uf)
            # Calculates the intensity Lambda (la) of the cluster, which is
            # defined almost as the Rayleigh quotient
            if wt > 0:
                la = vt.item() / (wt **2)
            else:
                la = 0

            # since lt*vf =(-lt)*(-vf), try symmetric version 
            # using -vf:
            vf1 = -vf

            bf1 = np.maximum(zeros_vect, vf1)
            uf1 = np.minimum(bf1, ones_vect)
            uf1 = np.squeeze(np.asarray(uf1))

            if LA.norm(uf1) > 0:
                uf1 = uf1 / LA.norm(uf1)
                
            vt1 = uf1.T.dot(At).dot(uf1)
            wt1 = uf1.T.dot(uf1)
            if wt1 > 0:
                la1 = vt1.item() / (wt1 **2)
            else:
                la1 = 0

            if la > la1:
                cur_intensities[k] = la
                vm[:, k] = uf.ravel()
            else:
                cur_intensities[k] = la1
                vm[:, k] = uf1.ravel()

        contrib_max, contrib_max_index = cur_intensities.max(), cur_intensities.argmax()
        if contrib_max > ZERO_BOUND:
            lat = np.append(lat, eig_vals[eig_vals_pos[contrib_max_index]])
            intensities = np.append(intensities, np.matrix([np.sqrt(contrib_max),
                                                            contrib_max]), axis=0)
            # square root and value of lambda intensity of cluster_got
            # square root shows the value of fuzzyness
            uf = vm[:, contrib_max_index]
            vt = uf.T.dot(At).dot(uf)
            wt = uf.T.dot(uf)

            membership_matrix = np.append(membership_matrix, np.matrix(uf).T, axis=1)
            # calculate residual similarity matrix:
            # remove the present cluster (i.e. itensity* membership) from
            # similarity matrix
            Att = At - contrib_max * np.matrix(uf).T * np.matrix(uf)
            At = (Att + Att.T) / 2
            matrix_sequence.append(At)

            curr_cont = (vt / wt) ** 2
            # Calculate the relative contribution of cluster_got
            curr_cont /= scatter
            contrib = np.append(contrib, curr_cont)
            # Calculate the residual contribution
            res_cont -= curr_cont
            cluster_got += 1
        else:
            is_positive = False

    if not is_positive:
        print('No positive weights at spectral clusters')
    elif curr_cont < min_cont:
        print('Cluster contribution is too small')
    elif res_cont < eps:
        print('Residual is too small')
    elif cluster_got > max_clust_num:
        print('Maximum number of clusters reached')

    return matrix_sequence, membership_matrix, contrib, intensities, lat, cluster_got


if __name__ == '__main__':

    M = np.matrix([[1, .5, .3,  .1],
                   [.5, 1, .98, .4],
                   [.3, .98, 1, .6],
                   [.1, .4, .6, 1 ]])
    #M = np.matrix([[1, 0, 1], [0, 3, 0], [1, 0, 9]])
    M = np.matrix(np.random.rand(500, 500))

    B, member, contrib, intensity, lat, tt = faddis(M)
    print("B")
    print(B)
    print("member")
    print(member)
    print("contrib")
    print(contrib)
    print("intensity")
    print(intensity)
    print("lat")
    print(lat)
    print("tt")
    print(tt)
# Out:
# Cluster contribution is too small
# B
# [matrix([[0.35243066, 0.36258678, 0.92027008, ..., 0.5435544 , 0.69995649,
#          0.60429098],
#         [0.36258678, 0.63354169, 0.50249713, ..., 0.57876935, 0.81993271,
#          0.36650739],
#         [0.92027008, 0.50249713, 0.24504618, ..., 0.41062836, 0.30363743,
#          0.45641049],
#         ...,
#         [0.5435544 , 0.57876935, 0.41062836, ..., 0.51127147, 0.9082341 ,
#          0.28337575],
#         [0.69995649, 0.81993271, 0.30363743, ..., 0.9082341 , 0.09049915,
#          0.53220939],
#         [0.60429098, 0.36650739, 0.45641049, ..., 0.28337575, 0.53220939,
#          0.71722806]]), matrix([[-0.11573511, -0.12586319,  0.43961036, ...,  0.04855073,
#           0.21026136,  0.11986343],
#         [-0.12586319,  0.12392867,  0.00101188, ...,  0.06231868,
#           0.30902058, -0.13890892],
#         [ 0.43961036,  0.00101188, -0.24844092, ..., -0.09758548,
#          -0.1991262 , -0.04094498],
#         ...,
#         [ 0.04855073,  0.06231868, -0.09758548, ..., -0.01210861,
#           0.39046689, -0.22882191],
#         [ 0.21026136,  0.30902058, -0.1991262 , ...,  0.39046689,
#          -0.42171541,  0.02550466],
#         [ 0.11986343, -0.13890892, -0.04094498, ..., -0.22882191,
#           0.02550466,  0.21597388]]), matrix([[-0.11573511, -0.12586319,  0.43961036, ...,  0.04855073,
#           0.21026136,  0.11986343],
#         [-0.12586319,  0.12392867,  0.00101188, ...,  0.06231868,
#           0.30902058, -0.13890892],
#         [ 0.43961036,  0.00101188, -0.32231253, ..., -0.09758548,
#          -0.1991262 , -0.05328999],
#         ...,
#         [ 0.04855073,  0.06231868, -0.09758548, ..., -0.01210861,
#           0.39046689, -0.22882191],
#         [ 0.21026136,  0.30902058, -0.1991262 , ...,  0.39046689,
#          -0.42171541,  0.02550466],
#         [ 0.11986343, -0.13890892, -0.05328999, ..., -0.22882191,
#           0.02550466,  0.21391086]])]
# member
# [[4.32632262e-02 0.00000000e+00]
#  [4.51376897e-02 0.00000000e+00]
#  [4.44177927e-02 1.23909113e-01]
#  [4.35724764e-02 0.00000000e+00]
#  [4.45476555e-02 1.57727185e-02]
#  [4.53769696e-02 0.00000000e+00]
#  [4.52050926e-02 0.00000000e+00]
#  [4.48189059e-02 1.01112584e-01]
#  [4.53608194e-02 0.00000000e+00]
#  [4.42587629e-02 9.49536617e-02]
#  [4.37689379e-02 1.38340078e-02]
#  [4.32744694e-02 0.00000000e+00]
#  [4.43687166e-02 0.00000000e+00]
#  [4.61679176e-02 0.00000000e+00]
#  [4.37904202e-02 6.76858275e-02]
#  [4.41476874e-02 3.35483482e-02]
#  [4.51827189e-02 0.00000000e+00]
#  [4.43103118e-02 0.00000000e+00]
#  [4.45053722e-02 0.00000000e+00]
#  [4.56251725e-02 1.62743098e-01]
#  [4.42570166e-02 0.00000000e+00]
#  [4.46359457e-02 0.00000000e+00]
#  [4.46620374e-02 0.00000000e+00]
#  [4.54363489e-02 7.03700409e-02]
#  [4.44720972e-02 3.53651816e-02]
#  [4.50134332e-02 8.06081353e-02]
#  [4.46079562e-02 0.00000000e+00]
#  [4.49233420e-02 3.55370464e-02]
#  [4.46651270e-02 7.39427846e-02]
#  [4.54878755e-02 6.23259828e-02]
#  [4.48905960e-02 4.69922308e-02]
#  [4.45185489e-02 3.83918908e-02]
#  [4.49969705e-02 1.11973090e-01]
#  [4.34501184e-02 0.00000000e+00]
#  [4.51337856e-02 1.83371349e-02]
#  [4.60616181e-02 0.00000000e+00]
#  [4.28046949e-02 2.79523899e-02]
#  [4.49318852e-02 0.00000000e+00]
#  [4.39048170e-02 0.00000000e+00]
#  [4.49767455e-02 5.29623988e-02]
#  [4.58609638e-02 0.00000000e+00]
#  [4.49248062e-02 1.53787146e-02]
#  [4.35283655e-02 8.84312950e-02]
#  [4.56627168e-02 0.00000000e+00]
#  [4.56393682e-02 1.04462587e-02]
#  [4.45376109e-02 6.59092844e-02]
#  [4.45493584e-02 0.00000000e+00]
#  [4.51790521e-02 0.00000000e+00]
#  [4.38057855e-02 0.00000000e+00]
#  [4.63394635e-02 6.14319103e-02]
#  [4.47969206e-02 0.00000000e+00]
#  [4.45833119e-02 0.00000000e+00]
#  [4.42217277e-02 2.19712564e-02]
#  [4.52140125e-02 0.00000000e+00]
#  [4.36587386e-02 0.00000000e+00]
#  [4.39174671e-02 0.00000000e+00]
#  [4.58376953e-02 2.61539503e-02]
#  [4.45414528e-02 7.64939899e-02]
#  [4.66778683e-02 2.55228382e-02]
#  [4.45481874e-02 0.00000000e+00]
#  [4.59190206e-02 5.51741843e-02]
#  [4.48462835e-02 7.85496075e-03]
#  [4.41059851e-02 0.00000000e+00]
#  [4.33718632e-02 2.01085670e-02]
#  [4.38387604e-02 0.00000000e+00]
#  [4.45088145e-02 0.00000000e+00]
#  [4.43076149e-02 0.00000000e+00]
#  [4.49822755e-02 0.00000000e+00]
#  [4.54087350e-02 3.99527075e-02]
#  [4.45356829e-02 0.00000000e+00]
#  [4.43083887e-02 2.68373148e-02]
#  [4.40014200e-02 9.11372059e-02]
#  [4.45956817e-02 0.00000000e+00]
#  [4.46713521e-02 2.53173845e-02]
#  [4.57433179e-02 0.00000000e+00]
#  [4.52527553e-02 0.00000000e+00]
#  [4.47659776e-02 2.07069935e-02]]
# contrib
# [7.51089640e-01 2.77913824e-04]
# intensity
# [[ 15.81542725 250.12773913]
#  [  2.19348932   4.81139538]]
# lat
# [250.12773913   9.0228831 ]
# tt
# 2

# %%
import numpy as np
import numpy.linalg as LA

ZERO_BOUND = 10 ** (-8)
ENTITY_BOUND = 10 ** (-4)


def lapin(A):
    A = (A + A.T) / 2
    a_sums = np.ravel(abs(sum(A)))
    checked = np.array(a_sums > ENTITY_BOUND)
    is_correct = checked.all()

    if not is_correct:
        print('These entities are no good - remove them first!!!')
        print([i for i, j in enumerate(checked, 1) if not j])
        A = A[:, checked][checked, :]
        a_sums = a_sums[checked]

    matrix_dim, _ = A.shape
    C = np.empty((matrix_dim, matrix_dim))
    for i in range(matrix_dim):
        for j in range(matrix_dim):
            C[i, j] = A[i, j] / np.sqrt(a_sums[i] * a_sums[j])

    eig_vals, eig_vecs = LA.eig(np.eye(matrix_dim) - C)
    eig_vals_diag = np.diag(eig_vals)
    nonzero_cond = np.array(eig_vals > ZERO_BOUND)
    nonzero_eig_vals_diag = eig_vals_diag[nonzero_cond, :][:, nonzero_cond]
    nonzero_eig_vecs = eig_vecs[:, nonzero_cond]
    B = nonzero_eig_vecs.dot(LA.inv(nonzero_eig_vals_diag)).dot(nonzero_eig_vecs.T)

    return B


if __name__ == '__main__':

    M = np.matrix([[1, 2, 1], [2, 4, 1], [1, 1, 9]])
    M = np.matrix([[1, 0, 1], [0, 3, 0], [1, 0, 9]])
    M_transformed = lapin(M)
    print(M_transformed)
# Out:
# [[ 1.38888889  0.         -0.62112999]
#  [ 0.          0.         -0.        ]
#  [-0.62112999 -0.          0.27777778]]

# %%
from operator import itemgetter

tc = relevance_matrix.dot(relevance_matrix.T)

# %%
from faddis import faddis
from lapin import lapin
from operator import itemgetter

# %%
tc_transformed = lapin(tc)

# %%
B, member, contrib, intensity, lat, tt = faddis(tc_transformed)
# Out:
# /Users/anastasiaibaeva/Desktop/диплом/pargenfs/faddis.py:124: ComplexWarning: Casting complex values to real discards the imaginary part
#   cur_intensities[k] = la1
# /Users/anastasiaibaeva/Desktop/диплом/pargenfs/faddis.py:125: ComplexWarning: Casting complex values to real discards the imaginary part
#   vm[:, k] = uf1.ravel()
# /Users/anastasiaibaeva/Desktop/диплом/pargenfs/faddis.py:121: ComplexWarning: Casting complex values to real discards the imaginary part
#   cur_intensities[k] = la
# /Users/anastasiaibaeva/Desktop/диплом/pargenfs/faddis.py:122: ComplexWarning: Casting complex values to real discards the imaginary part
#   vm[:, k] = uf.ravel()
# Cluster contribution is too small

# %%
np.savetxt("clusters.dat", member)

# %%
for cluster in member.T:
    print(list(sorted(zip(titles, cluster.flat), key=itemgetter(1), reverse=True))[:3], '\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0b0a13d9b42a> in <module>
#       1 for cluster in member.T:
# ----> 2     print(list(sorted(zip(titles, cluster.flat), key=itemgetter(1), reverse=True))[:3], '\n')
#
# NameError: name 'titles' is not defined

# %%
# !python3 pargenfs.py Data_Science_taxonomy.csv taxonomy_leaves.txt clusters.dat 0
# Out:
# Number of leaves: 351
# All positive weights:
# bayesian analysis                                            0.31843
# canonical correlation analysis                               0.24021
# factor analysis                                              0.22553
# mixture modeling                                             0.19191
# lifelong machine learning                                    0.18885
# modelling                                                    0.18657
# fusion of classifiers                                        0.16400
# object recognition                                           0.16318
# least moduli                                                 0.15447
# q-learning                                                   0.15015
# sequential monte carlo methods                               0.14405
# database query languages                                     0.14215
# cross-validation                                             0.12816
# support vector machines                                      0.12749
# support vector machines                                      0.12749
# markov decision processes                                    0.12531
# markov decision processes                                    0.12531
# regret bounds                                                0.12506
# natural language generation                                  0.12405
# deep web                                                     0.11671
# task models                                                  0.11189
# rank aggregation                                             0.11132
# shape inference                                              0.11050
# online learning theory                                       0.11038
# query suggestion                                             0.10513
# object identification                                        0.10491
# entity resolution                                            0.10413
# tensor representation                                        0.10301
# ontologies                                                   0.09486
# markov network models                                        0.09367
# stochastic games                                             0.09239
# neuro-fuzzy approach                                         0.09124
# structured prediction                                        0.08780
# music retrieval                                              0.08747
# structured outputs                                           0.08632
# dbms engine architectures                                    0.08598
# xquery                                                       0.08446
# self organized map                                           0.08368
# max marginal computation                                     0.08348
# phonology                                                    0.08175
# data streams                                                 0.08174
# motif discovery                                              0.08011
# inverse reinforcement learning                               0.07917
# inverse reinforcement learning                               0.07917
# adversarial learning                                         0.07740
# adversarial learning                                         0.07740
# data provenance                                              0.07698
# data provenance                                              0.07698
# deep belief networks                                         0.07695
# nonlinear principal components                               0.07666
# scientific visualization                                     0.07657
# desktop search                                               0.07329
# cluster analysis                                             0.07013
# cluster analysis                                             0.07013
# cost-sensitive learning                                      0.06868
# database recovery                                            0.06800
# web log analysis                                             0.06722
# record and buffer management                                 0.06367
# consensus clustering                                         0.06270
# cognitive robotics                                           0.06233
# structured text search                                       0.06182
# additive clustering                                          0.05887
# gaussian processes                                           0.05873
# gaussian processes                                           0.05873
# multi-agent learning                                         0.05341
# vagueness and fuzzy logic                                    0.05339
# sparse pca                                                   0.05238
# online analytical processing engines                         0.05172
# maximum a posteriori modeling                                0.05147
# inductive logic learning                                     0.05145
# anomaly detection                                            0.04838
# anomaly detection                                            0.04838
# hyperbolic trees                                             0.04832
# graph drawings                                               0.04788
# search interfaces                                            0.04759
# markov-chain monte carlo convergence measures                0.04703
# key-phrase indexing                                          0.04657
# main memory engines                                          0.04634
# mathematics retrieval                                        0.04594
# frequent graph mining                                        0.04527
# fuzzy clustering                                             0.04475
# personalization                                              0.04454
# causal networks                                              0.04383
# data structures and algorithms for data management           0.04356
# item-based                                                   0.04313
# content analysis and feature selection                       0.04304
# data cleaning                                                0.04226
# data cleaning                                                0.04226
# near-duplicate and plagiarism detection                      0.04215
# query optimization                                           0.04115
# language resources                                           0.04087
# latent dirichlet allocation                                  0.04075
# feature weight clustering                                    0.04062
# theory of database privacy and security                      0.04031
# top-k retrieval in databases                                 0.03989
# apprenticeship learning                                      0.03898
# apprenticeship learning                                      0.03898
# shape representations                                        0.03883
# presentation of retrieval results                            0.03872
# deadlocks                                                    0.03868
# types of association rules                                   0.03855
# model trees                                                  0.03838
# image search                                                 0.03773
# temporal data                                                0.03665
# equational models                                            0.03664
# site wrapping                                                0.03641
# document topic models                                        0.03566
# spectral clustering                                          0.03558
# document collection models                                   0.03556
# graph embedding                                              0.03553
# process mining                                               0.03364
# data encryption                                              0.03325
# query representation                                         0.03287
# reasoning about belief and knowledge                         0.03259
# variational methods                                          0.03127
# inconsistent data                                            0.03070
# geographic visualization                                     0.03007
# learning from critiques                                      0.02982
# database interoperability                                    0.02906
# speech                                                       0.02849
# query log analysis                                           0.02775
# empirical studies in visualization                           0.02704
# biclustering                                                 0.02526
# batch learning                                               0.02514
# xpath                                                        0.02498
# relational parallel and distributed dbmss                    0.02486
# dimensionality reduction                                     0.02439
# information retrieval diversity                              0.02418
# chemical and biochemical retrieval                           0.02410
# database constraints theory                                  0.02378
# conceptual clustering                                        0.02365
# kernel density estimators                                    0.02365
# visualization toolkits                                       0.02137
# knowledge discovery                                          0.02102
# recommender systems                                          0.02095
# semi-structured data                                         0.01897
# statistical graphics                                         0.01884
# formal concept analysis                                      0.01854
# topic modeling                                               0.01853
# sentiment analysis                                           0.01798
# inductive inference                                          0.01713
# key-value stores                                             0.01504
# dictionaries                                                 0.01480
# ranking                                                      0.01395
# probabilistic reasoning                                      0.01349
# metropolis-hastings algorithm                                0.01339
# transfer learning                                            0.01237
# expert search                                                0.01101
# distributed database recovery                                0.00957
# factor graphs                                                0.00944
# traffic analysis                                             0.00897
# logic programming and answer set programming                 0.00872
# integrity checking                                           0.00870
# markov networks                                              0.00865
# policy iteration                                             0.00765
# multi-agent reinforcement learning                           0.00665
# multi-agent reinforcement learning                           0.00665
# bootstrapping                                                0.00591
# latent variable models                                       0.00587
# random number generation                                     0.00579
# rule and pattern discovery                                   0.00504
# spline models                                                0.00489
# matching                                                     0.00488
# source separation                                            0.00484
# query operators                                              0.00436
# models of learning                                           0.00344
# bayesian network models                                      0.00315
# deduplication                                                0.00302
# loopy belief propagation                                     0.00218
# graph partitioning                                           0.00184
# temporal reasoning                                           0.00154
# active learning settings                                     0.00020
# After transformation:
# bayesian analysis                                            0.49299
# canonical correlation analysis                               0.37190
# factor analysis                                              0.34917
# mixture modeling                                             0.29711
# lifelong machine learning                                    0.29238
# modelling                                                    0.28885
# fusion of classifiers                                        0.25390
# object recognition                                           0.25264
# least moduli                                                 0.23916
# q-learning                                                   0.23247
# Setting weights for internal nodes
# Membership in root: 1.00000
# Pruning tree...
# Setting gaps...
# Other parameters setting...
# ParGenFS main steps...
# Done. Saving...
# Table saved in the file: table.csv
# ete representation saved in the file: taxonomy_tree_lifted.ete
# ete representation saved.
# Done.

# %%
# !python3 pargenfs.py Data_Science_taxonomy.csv taxonomy_leaves.txt clusters.dat 1
# Out:
# Number of leaves: 351
# All positive weights:
# feature selection                                            0.32607
# kernel-based clustering                                      0.32370
# semi-supervised learning                                     0.22434
# decision diagrams                                            0.19681
# approximate dynamic programming methods                      0.19348
# unidimensional range search                                  0.16934
# bagging                                                      0.16728
# value iteration                                              0.16429
# ensembling                                                   0.12945
# exploratory data analysis                                    0.12915
# retrieval efficiency                                         0.12889
# surfacing                                                    0.12436
# learning to rank                                             0.12318
# learning to rank                                             0.12318
# logic and databases                                          0.11994
# data compression                                             0.11355
# evolving nn                                                  0.11328
# time series analysis                                         0.11328
# boosting                                                     0.11247
# boosting                                                     0.11247
# sample complexity and generalization bounds                  0.11147
# call level interfaces                                        0.10875
# dendrograms                                                  0.10814
# interest point and salient region detections                 0.10496
# data locking                                                 0.09789
# mixture models                                               0.09478
# multiresolution                                              0.09307
# variable elimination                                         0.08935
# boolean function learning                                    0.08918
# enterprise search                                            0.08889
# data warehouses                                              0.08863
# summarization                                                0.08852
# factorial hmm                                                0.08594
# learning under covariate shift                               0.08489
# wikipedia based semantics                                    0.08415
# maximum likelihood modeling                                  0.08406
# partially-observable markov decision processes               0.08337
# visual analytics                                             0.08331
# rule-based netwok archirtecture                              0.08278
# distributed data locking                                     0.08270
# learning from implicit feedback                              0.08205
# relational database model                                    0.08181
# expectation maximization                                     0.07990
# computing most probable explanation                          0.07969
# spatial and physical reasoning                               0.07767
# nearest-neighbor search                                      0.07690
# similarity measures                                          0.07672
# query learning                                               0.07541
# video search                                                 0.07442
# independent component analysis                               0.07359
# treemaps                                                     0.07285
# dynamic                                                      0.07243
# web and social media search                                  0.07069
# scalable                                                     0.06981
# splittting criteria                                          0.06977
# mediators and data integration                               0.06800
# document filtering                                           0.06668
# hierarchical representations                                 0.06653
# critical nodes detection                                     0.06486
# massive data clustering                                      0.06480
# stochastic differential equations                            0.06476
# perceptron algorithm                                         0.06329
# data modeling                                                0.06189
# machine translation                                          0.06109
# structured query language                                    0.05806
# bayesian computation                                         0.05799
# language models                                              0.05772
# generalized eigenvalue                                       0.05742
# retrieval effectiveness                                      0.05656
# reconstruction                                               0.05531
# fuzzy representation                                         0.05501
# sequential decision making                                   0.05490
# sequential decision making                                   0.05490
# description logics                                           0.05393
# test collections                                             0.05374
# heat maps                                                    0.05328
# information visualization                                    0.05278
# learning from demonstrations                                 0.05268
# cladograms                                                   0.05228
# queueing theory                                              0.05144
# kernel independent components                                0.05100
# online learning settings                                     0.05008
# maximum likelihood estimation                                0.04601
# network data models                                          0.04585
# appearance and texture representations                       0.04511
# thesauri                                                     0.04463
# database views                                               0.04397
# tracking                                                     0.04312
# data exchange                                                0.04249
# data exchange                                                0.04249
# incomplete data                                              0.04169
# stream management                                            0.04049
# speech recognition                                           0.04025
# temporal difference learning                                 0.03988
# contingency table analysis                                   0.03979
# wrappers                                                     0.03931
# survival analysis                                            0.03911
# supervised learning by classification                        0.03808
# parallel computation                                         0.03720
# uncertainty                                                  0.03669
# text categorization                                          0.03573
# query intent                                                 0.03306
# transaction logging                                          0.03222
# unsupervised learning and clustering                         0.03217
# markov processes                                             0.03194
# probabilistic retrieval models                               0.03137
# causal reasoning and diagnostics                             0.03118
# supervised learning by regression                            0.03072
# interestingness                                              0.03033
# gibbs sampling                                               0.02924
# hierarchical data models                                     0.02873
# jackknifing                                                  0.02841
# market graph                                                 0.02834
# object detection                                             0.02806
# search results deduplication                                 0.02792
# record and block layout                                      0.02707
# elastic maps                                                 0.02641
# 2d pca                                                       0.02637
# 2d pca                                                       0.02637
# semantic networks                                            0.02590
# mapreduce languages                                          0.02529
# non-negative matrix factorization                            0.02477
# hypothesis testing and confidence interval computation       0.02361
# triggers and rules                                           0.02350
# instance-based learning                                      0.02347
# statistical relational learning                              0.02154
# data scans                                                   0.02070
# multivariate statistics                                      0.02056
# document structure                                           0.02037
# evolutionary approach                                        0.02036
# trajectory clustering                                        0.01986
# graph based conceptual clustering                            0.01764
# nonparametric statistics                                     0.01661
# parallel implementation                                      0.01605
# active learning                                              0.01566
# distribution functions                                       0.01471
# physical data models                                         0.01429
# point lookups                                                0.01425
# collaborative search                                         0.01337
# data mining tools                                            0.01321
# question answering                                           0.01240
# entity relationship models                                   0.01167
# bayesian networks                                            0.01097
# multilingual and cross-lingual retrieval                     0.01094
# mapreduce-based systems                                      0.01019
# relevance assessment                                         0.00843
# bayesian nonparametric models                                0.00837
# database query processing and optimization                   0.00834
# query reformulation                                          0.00816
# multidimensional range search                                0.00811
# data stream mining                                           0.00806
# kernel matrix                                                0.00775
# data encoding and canonicalization                           0.00754
# information extraction                                       0.00693
# information extraction                                       0.00693
# maximum entropy modeling                                     0.00542
# image segmentation                                           0.00515
# novelty in information retrieval                             0.00455
# ontology engineering                                         0.00455
# video segmentation                                           0.00421
# proximity search                                             0.00400
# renewal theory                                               0.00333
# visualization design and evaluation methods                  0.00309
# clustering and classification                                0.00263
# supervised dimesionality reduction                           0.00253
# join algorithms                                              0.00228
# robust regression                                            0.00201
# data integration                                             0.00152
# simulated annealing                                          0.00135
# business intelligence                                        0.00109
# probabilistic algorithms                                     0.00022
# After transformation:
# feature selection                                            0.50239
# kernel-based clustering                                      0.49874
# semi-supervised learning                                     0.34565
# decision diagrams                                            0.30323
# approximate dynamic programming methods                      0.29811
# unidimensional range search                                  0.26091
# bagging                                                      0.25773
# value iteration                                              0.25313
# Setting weights for internal nodes
# Membership in root: 1.00000
# Pruning tree...
# Setting gaps...
# Other parameters setting...
# ParGenFS main steps...
# Done. Saving...
# Table saved in the file: table.csv
# ete representation saved in the file: taxonomy_tree_lifted.ete
# ete representation saved.
# Done.

# %%
# !python3 pargenfs.py Data_Science_taxonomy.csv taxonomy_leaves.txt clusters.dat 2
# Out:
# Number of leaves: 351
# All positive weights:
# sample complexity and generalization bounds                  0.50953
# video search                                                 0.39376
# kernel-based clustering                                      0.37435
# spatial and physical reasoning                               0.15668
# incomplete data                                              0.15181
# semi-supervised learning                                     0.15034
# decision diagrams                                            0.14855
# ensembling                                                   0.14104
# mixture models                                               0.13784
# statistical relational learning                              0.10894
# cladograms                                                   0.09514
# hierarchical representations                                 0.09257
# query learning                                               0.09079
# boolean function learning                                    0.08945
# database views                                               0.08759
# time series analysis                                         0.08559
# structured query language                                    0.08416
# independent component analysis                               0.08369
# retrieval efficiency                                         0.08321
# scalable                                                     0.07901
# cross-validation                                             0.07876
# variable elimination                                         0.07870
# web log analysis                                             0.07854
# elastic maps                                                 0.07838
# types of association rules                                   0.07479
# enterprise search                                            0.07351
# call level interfaces                                        0.07251
# temporal reasoning                                           0.07242
# graph based conceptual clustering                            0.07238
# evolving nn                                                  0.07204
# treemaps                                                     0.06861
# non-negative matrix factorization                            0.06739
# mediators and data integration                               0.06608
# test collections                                             0.06578
# ontology engineering                                         0.06493
# clustering and classification                                0.06208
# wikipedia based semantics                                    0.06089
# data locking                                                 0.06047
# triggers and rules                                           0.06031
# recommender systems                                          0.06031
# interest point and salient region detections                 0.06008
# thesauri                                                     0.05985
# evolutionary approach                                        0.05638
# maximum likelihood estimation                                0.05581
# data warehouses                                              0.05546
# question answering                                           0.05530
# distributed data locking                                     0.05485
# jackknifing                                                  0.05484
# reconstruction                                               0.05431
# sequential decision making                                   0.05418
# sequential decision making                                   0.05418
# q-learning                                                   0.05297
# novelty in information retrieval                             0.05225
# fusion of classifiers                                        0.05209
# text categorization                                          0.05165
# data modeling                                                0.05085
# parallel implementation                                      0.05079
# graph partitioning                                           0.04971
# massive data clustering                                      0.04841
# maximum a posteriori modeling                                0.04834
# value iteration                                              0.04782
# speech recognition                                           0.04769
# mapreduce-based systems                                      0.04756
# bayesian network models                                      0.04443
# query intent                                                 0.04328
# reasoning about belief and knowledge                         0.04291
# stochastic differential equations                            0.04281
# dictionaries                                                 0.04237
# empirical studies in visualization                           0.04174
# nearest-neighbor search                                      0.04144
# partially-observable markov decision processes               0.04064
# document filtering                                           0.03971
# image search                                                 0.03920
# computing most probable explanation                          0.03915
# kernel matrix                                                0.03777
# maximum likelihood modeling                                  0.03753
# robust regression                                            0.03735
# bootstrapping                                                0.03631
# collaborative search                                         0.03611
# web and social media search                                  0.03596
# probabilistic algorithms                                     0.03582
# data compression                                             0.03576
# unidimensional range search                                  0.03477
# survival analysis                                            0.03365
# record and block layout                                      0.03293
# distribution functions                                       0.03286
# interestingness                                              0.03223
# maximum entropy modeling                                     0.03148
# semantic networks                                            0.03122
# probabilistic reasoning                                      0.03091
# information visualization                                    0.03065
# visual analytics                                             0.02998
# logic programming and answer set programming                 0.02975
# uncertainty                                                  0.02973
# surfacing                                                    0.02955
# instance-based learning                                      0.02944
# query suggestion                                             0.02919
# structured text search                                       0.02843
# object detection                                             0.02826
# language models                                              0.02809
# sparse pca                                                   0.02806
# query reformulation                                          0.02779
# bagging                                                      0.02737
# database query processing and optimization                   0.02703
# relational database model                                    0.02625
# expert search                                                0.02625
# temporal data                                                0.02578
# key-phrase indexing                                          0.02541
# spline models                                                0.02524
# dynamic                                                      0.02442
# market graph                                                 0.02334
# random number generation                                     0.02289
# apprenticeship learning                                      0.02238
# apprenticeship learning                                      0.02238
# fuzzy representation                                         0.02147
# inductive logic learning                                     0.02068
# rule and pattern discovery                                   0.02028
# markov processes                                             0.01917
# similarity measures                                          0.01910
# speech                                                       0.01905
# learning from implicit feedback                              0.01877
# active learning                                              0.01876
# site wrapping                                                0.01852
# contingency table analysis                                   0.01823
# feature selection                                            0.01816
# entity relationship models                                   0.01746
# traffic analysis                                             0.01693
# rule-based netwok archirtecture                              0.01598
# neuro-fuzzy approach                                         0.01598
# bayesian nonparametric models                                0.01470
# logic and databases                                          0.01459
# network data models                                          0.01453
# cost-sensitive learning                                      0.01431
# dendrograms                                                  0.01370
# image segmentation                                           0.01361
# geographic visualization                                     0.01319
# query log analysis                                           0.01259
# matching                                                     0.01195
# causal networks                                              0.01125
# supervised learning by regression                            0.01120
# dbms engine architectures                                    0.01014
# visualization design and evaluation methods                  0.00978
# bayesian computation                                         0.00975
# document structure                                           0.00963
# tracking                                                     0.00957
# join algorithms                                              0.00912
# multivariate statistics                                      0.00892
# music retrieval                                              0.00886
# active learning settings                                     0.00882
# structured outputs                                           0.00868
# causal reasoning and diagnostics                             0.00866
# point lookups                                                0.00837
# supervised learning by classification                        0.00742
# policy iteration                                             0.00693
# renewal theory                                               0.00622
# nonlinear principal components                               0.00406
# heat maps                                                    0.00385
# approximate dynamic programming methods                      0.00337
# wrappers                                                     0.00325
# xpath                                                        0.00317
# deduplication                                                0.00238
# key-value stores                                             0.00192
# probabilistic retrieval models                               0.00108
# learning to rank                                             0.00068
# learning to rank                                             0.00068
# language resources                                           0.00021
# multidimensional range search                                0.00010
# After transformation:
# sample complexity and generalization bounds                  0.64451
# video search                                                 0.49807
# kernel-based clustering                                      0.47352
# spatial and physical reasoning                               0.19819
# incomplete data                                              0.19202
# semi-supervised learning                                     0.19017
# Setting weights for internal nodes
# Membership in root: 1.00000
# Pruning tree...
# Setting gaps...
# Other parameters setting...
# ParGenFS main steps...
# Done. Saving...
# Table saved in the file: table.csv
# ete representation saved in the file: taxonomy_tree_lifted.ete
# ete representation saved.
# Done.

# %%
# !python3 pargenfs.py Data_Science_taxonomy.csv taxonomy_leaves.txt clusters.dat 3
# Out:
# Number of leaves: 351
# All positive weights:
# bayesian analysis                                            0.40910
# factor analysis                                              0.35236
# modelling                                                    0.26800
# temporal difference learning                                 0.26135
# max marginal computation                                     0.20840
# inverse reinforcement learning                               0.17352
# inverse reinforcement learning                               0.17352
# online learning settings                                     0.15226
# database query languages                                     0.14502
# deep web                                                     0.14336
# cognitive robotics                                           0.14049
# least moduli                                                 0.13993
# multiresolution                                              0.12765
# natural language generation                                  0.12506
# markov network models                                        0.11337
# mixture modeling                                             0.11090
# semi-structured data                                         0.10728
# self organized map                                           0.10624
# object recognition                                           0.09822
# tensor representation                                        0.09629
# personalization                                              0.09518
# transfer learning                                            0.09501
# formal concept analysis                                      0.09390
# motif discovery                                              0.08499
# adversarial learning                                         0.08425
# adversarial learning                                         0.08425
# sequential monte carlo methods                               0.08131
# data streams                                                 0.08050
# factor graphs                                                0.08047
# kernel independent components                                0.07898
# factorial hmm                                                0.07764
# consensus clustering                                         0.07612
# inconsistent data                                            0.07604
# markov decision processes                                    0.07429
# markov decision processes                                    0.07429
# regret bounds                                                0.07334
# structured prediction                                        0.06587
# stochastic games                                             0.06513
# data encoding and canonicalization                           0.06385
# online learning theory                                       0.06385
# shape representations                                        0.06280
# models of learning                                           0.06234
# support vector machines                                      0.06225
# support vector machines                                      0.06225
# expectation maximization                                     0.06201
# presentation of retrieval results                            0.06041
# desktop search                                               0.06016
# multi-agent learning                                         0.05963
# topic modeling                                               0.05873
# deep belief networks                                         0.05865
# lifelong machine learning                                    0.05780
# theory of database privacy and security                      0.05775
# data stream mining                                           0.05622
# canonical correlation analysis                               0.05563
# proximity search                                             0.05354
# record and buffer management                                 0.05351
# markov networks                                              0.05325
# latent dirichlet allocation                                  0.05174
# relevance assessment                                         0.05166
# deadlocks                                                    0.05011
# vagueness and fuzzy logic                                    0.04992
# task models                                                  0.04871
# online analytical processing engines                         0.04822
# item-based                                                   0.04768
# near-duplicate and plagiarism detection                      0.04750
# information extraction                                       0.04728
# information extraction                                       0.04728
# xquery                                                       0.04634
# database constraints theory                                  0.04560
# content analysis and feature selection                       0.04416
# rank aggregation                                             0.04220
# transaction logging                                          0.04149
# variational methods                                          0.04132
# object identification                                        0.04121
# video segmentation                                           0.04089
# distributed database recovery                                0.04051
# boosting                                                     0.04024
# boosting                                                     0.04024
# perceptron algorithm                                         0.03767
# critical nodes detection                                     0.03747
# parallel computation                                         0.03741
# process mining                                               0.03725
# top-k retrieval in databases                                 0.03723
# supervised dimesionality reduction                           0.03694
# entity resolution                                            0.03654
# data encryption                                              0.03567
# data mining tools                                            0.03263
# latent variable models                                       0.03261
# ranking                                                      0.03208
# unsupervised learning and clustering                         0.03135
# metropolis-hastings algorithm                                0.03044
# trajectory clustering                                        0.03030
# bayesian networks                                            0.02932
# dimensionality reduction                                     0.02885
# document topic models                                        0.02803
# frequent graph mining                                        0.02795
# data provenance                                              0.02625
# data provenance                                              0.02625
# kernel density estimators                                    0.02448
# data exchange                                                0.02442
# data exchange                                                0.02442
# queueing theory                                              0.02366
# visualization toolkits                                       0.02306
# graph drawings                                               0.02178
# ontologies                                                   0.02154
# conceptual clustering                                        0.02059
# database recovery                                            0.02024
# description logics                                           0.02021
# hypothesis testing and confidence interval computation       0.02004
# database interoperability                                    0.01937
# phonology                                                    0.01910
# mathematics retrieval                                        0.01835
# statistical graphics                                         0.01814
# fuzzy clustering                                             0.01810
# batch learning                                               0.01798
# data integration                                             0.01741
# exploratory data analysis                                    0.01722
# hierarchical data models                                     0.01682
# summarization                                                0.01673
# learning under covariate shift                               0.01652
# integrity checking                                           0.01643
# markov-chain monte carlo convergence measures                0.01617
# information retrieval diversity                              0.01557
# retrieval effectiveness                                      0.01510
# data scans                                                   0.01426
# machine translation                                          0.01367
# simulated annealing                                          0.01349
# spectral clustering                                          0.01327
# sentiment analysis                                           0.01314
# data structures and algorithms for data management           0.01300
# multi-agent reinforcement learning                           0.01247
# multi-agent reinforcement learning                           0.01247
# biclustering                                                 0.01202
# appearance and texture representations                       0.01183
# feature weight clustering                                    0.01116
# physical data models                                         0.01073
# hyperbolic trees                                             0.01026
# relational parallel and distributed dbmss                    0.01019
# search results deduplication                                 0.00965
# learning from demonstrations                                 0.00963
# mapreduce languages                                          0.00956
# model trees                                                  0.00954
# equational models                                            0.00827
# business intelligence                                        0.00818
# query operators                                              0.00743
# source separation                                            0.00716
# inductive inference                                          0.00661
# learning from critiques                                      0.00624
# shape inference                                              0.00566
# main memory engines                                          0.00564
# gibbs sampling                                               0.00537
# anomaly detection                                            0.00413
# anomaly detection                                            0.00413
# generalized eigenvalue                                       0.00375
# 2d pca                                                       0.00348
# 2d pca                                                       0.00348
# loopy belief propagation                                     0.00344
# query optimization                                           0.00326
# stream management                                            0.00299
# splittting criteria                                          0.00278
# gaussian processes                                           0.00251
# gaussian processes                                           0.00251
# learning to rank                                             0.00217
# learning to rank                                             0.00217
# approximate dynamic programming methods                      0.00205
# document collection models                                   0.00187
# knowledge discovery                                          0.00174
# nonparametric statistics                                     0.00160
# scientific visualization                                     0.00132
# additive clustering                                          0.00104
# chemical and biochemical retrieval                           0.00021
# multilingual and cross-lingual retrieval                     0.00018
# search interfaces                                            0.00017
# After transformation:
# bayesian analysis                                            0.54743
# factor analysis                                              0.47150
# modelling                                                    0.35862
# temporal difference learning                                 0.34972
# max marginal computation                                     0.27886
# inverse reinforcement learning                               0.23219
# inverse reinforcement learning                               0.23219
# online learning settings                                     0.20375
# Setting weights for internal nodes
# Membership in root: 1.00000
# Pruning tree...
# Setting gaps...
# Other parameters setting...
# ParGenFS main steps...
# Done. Saving...
# Table saved in the file: table.csv
# ete representation saved in the file: taxonomy_tree_lifted.ete
# ete representation saved.
# Done.

# %%
# !python3 pargenfs.py Data_Science_taxonomy.csv taxonomy_leaves.txt clusters.dat 4
# Out:
# Number of leaves: 351
# All positive weights:
# feature selection                                            0.37080
# approximate dynamic programming methods                      0.22638
# temporal difference learning                                 0.21215
# multiresolution                                              0.18933
# bagging                                                      0.17873
# unidimensional range search                                  0.17648
# semi-supervised learning                                     0.16342
# value iteration                                              0.16150
# exploratory data analysis                                    0.16143
# boosting                                                     0.15685
# boosting                                                     0.15685
# online learning settings                                     0.15491
# factorial hmm                                                0.15088
# learning to rank                                             0.14445
# learning to rank                                             0.14445
# decision diagrams                                            0.13269
# expectation maximization                                     0.13178
# logic and databases                                          0.13159
# kernel-based clustering                                      0.12997
# surfacing                                                    0.12667
# dendrograms                                                  0.11799
# summarization                                                0.11355
# data compression                                             0.11073
# kernel independent components                                0.10954
# learning under covariate shift                               0.10935
# critical nodes detection                                     0.09956
# perceptron algorithm                                         0.09705
# retrieval efficiency                                         0.09558
# rule-based netwok archirtecture                              0.08704
# evolving nn                                                  0.08502
# learning from implicit feedback                              0.08439
# interest point and salient region detections                 0.08366
# splittting criteria                                          0.08330
# machine translation                                          0.08011
# call level interfaces                                        0.07934
# relational database model                                    0.07906
# visual analytics                                             0.07785
# similarity measures                                          0.07774
# time series analysis                                         0.07586
# retrieval effectiveness                                      0.07558
# description logics                                           0.07546
# queueing theory                                              0.07493
# data locking                                                 0.07490
# maximum likelihood modeling                                  0.07369
# partially-observable markov decision processes               0.07110
# generalized eigenvalue                                       0.06936
# dynamic                                                      0.06846
# learning from demonstrations                                 0.06781
# computing most probable explanation                          0.06757
# data warehouses                                              0.06718
# parallel computation                                         0.06702
# data exchange                                                0.06541
# data exchange                                                0.06541
# nearest-neighbor search                                      0.06319
# transaction logging                                          0.06309
# bayesian computation                                         0.06158
# distributed data locking                                     0.06073
# heat maps                                                    0.05999
# appearance and texture representations                       0.05952
# web and social media search                                  0.05920
# wikipedia based semantics                                    0.05811
# ensembling                                                   0.05792
# unsupervised learning and clustering                         0.05714
# enterprise search                                            0.05509
# variable elimination                                         0.05284
# document filtering                                           0.05201
# semi-structured data                                         0.05098
# fuzzy representation                                         0.05039
# transfer learning                                            0.05037
# language models                                              0.04947
# data encoding and canonicalization                           0.04942
# stream management                                            0.04844
# stochastic differential equations                            0.04760
# max marginal computation                                     0.04679
# boolean function learning                                    0.04511
# hierarchical data models                                     0.04478
# data stream mining                                           0.04467
# network data models                                          0.04453
# wrappers                                                     0.04425
# tracking                                                     0.04408
# factor graphs                                                0.04373
# massive data clustering                                      0.04365
# relevance assessment                                         0.04268
# formal concept analysis                                      0.04256
# trajectory clustering                                        0.04202
# information visualization                                    0.04158
# hypothesis testing and confidence interval computation       0.04024
# supervised learning by classification                        0.03984
# treemaps                                                     0.03973
# data modeling                                                0.03856
# search results deduplication                                 0.03838
# models of learning                                           0.03837
# proximity search                                             0.03834
# gibbs sampling                                               0.03784
# information extraction                                       0.03728
# information extraction                                       0.03728
# probabilistic retrieval models                               0.03591
# data mining tools                                            0.03577
# mediators and data integration                               0.03548
# mapreduce languages                                          0.03548
# contingency table analysis                                   0.03476
# data scans                                                   0.03309
# 2d pca                                                       0.03264
# 2d pca                                                       0.03264
# bayesian networks                                            0.03154
# causal reasoning and diagnostics                             0.03126
# video segmentation                                           0.03119
# independent component analysis                               0.03058
# supervised learning by regression                            0.02884
# reconstruction                                               0.02877
# scalable                                                     0.02865
# inverse reinforcement learning                               0.02840
# inverse reinforcement learning                               0.02840
# sequential decision making                                   0.02834
# sequential decision making                                   0.02834
# query learning                                               0.02798
# markov networks                                              0.02632
# supervised dimesionality reduction                           0.02607
# markov processes                                             0.02436
# cognitive robotics                                           0.02423
# survival analysis                                            0.02395
# uncertainty                                                  0.02347
# physical data models                                         0.02338
# nonparametric statistics                                     0.02034
# mixture models                                               0.01879
# test collections                                             0.01877
# topic modeling                                               0.01874
# multivariate statistics                                      0.01852
# document structure                                           0.01807
# market graph                                                 0.01795
# maximum likelihood estimation                                0.01737
# inconsistent data                                            0.01663
# distributed database recovery                                0.01621
# hierarchical representations                                 0.01604
# speech recognition                                           0.01559
# latent variable models                                       0.01545
# object detection                                             0.01441
# interestingness                                              0.01438
# personalization                                              0.01402
# multilingual and cross-lingual retrieval                     0.01323
# data integration                                             0.01241
# thesauri                                                     0.01225
# structured query language                                    0.01217
# point lookups                                                0.01156
# simulated annealing                                          0.00987
# multidimensional range search                                0.00970
# record and block layout                                      0.00947
# query intent                                                 0.00944
# semantic networks                                            0.00935
# instance-based learning                                      0.00780
# text categorization                                          0.00758
# business intelligence                                        0.00666
# active learning                                              0.00598
# ranking                                                      0.00595
# metropolis-hastings algorithm                                0.00509
# database constraints theory                                  0.00385
# entity relationship models                                   0.00210
# integrity checking                                           0.00135
# multi-agent reinforcement learning                           0.00103
# multi-agent reinforcement learning                           0.00103
# query operators                                              0.00021
# loopy belief propagation                                     0.00012
# After transformation:
# feature selection                                            0.52050
# approximate dynamic programming methods                      0.31778
# temporal difference learning                                 0.29781
# multiresolution                                              0.26577
# bagging                                                      0.25089
# unidimensional range search                                  0.24774
# semi-supervised learning                                     0.22939
# value iteration                                              0.22670
# exploratory data analysis                                    0.22660
# boosting                                                     0.22017
# boosting                                                     0.22017
# online learning settings                                     0.21746
# factorial hmm                                                0.21180
# Setting weights for internal nodes
# Membership in root: 1.00000
# Pruning tree...
# Setting gaps...
# Other parameters setting...
# ParGenFS main steps...
# Done. Saving...
# Table saved in the file: table.csv
# ete representation saved in the file: taxonomy_tree_lifted.ete
# ete representation saved.
# Done.
